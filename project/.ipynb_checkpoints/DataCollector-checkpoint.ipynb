# %%
import gentype

# %%
gentype.ping()
# Out:
# True

# %%
model = gentype.GibbsSampler()

# %%
es = gentype.Ensembl()

# %%
es.get_samples()
# Out:
# ['NA21144',
#  'NA21143',
#  'NA21142',
#  'NA21141',
#  'NA21137',
#  'NA21135',
#  'NA21133',
#  'NA21130',
#  'NA21129',
#  'NA21128',
#  'NA21127',
#  'NA21126',
#  'NA21125',
#  'NA21124',
#  'NA21123',
#  'NA21122',
#  'NA21120',
#  'NA21119',
#  'NA21118',
#  'NA21117',
#  'NA21116',
#  'NA21115',
#  'NA21114',
#  'NA21113',
#  'NA21112',
#  'NA21111',
#  'NA21110',
#  'NA21109',
#  'NA21108',
#  'NA21107',
#  'NA21106',
#  'NA21105',
#  'NA21104',
#  'NA21103',
#  'NA21102',
#  'NA21101',
#  'NA21100',
#  'NA21099',
#  'NA21098',
#  'NA21097',
#  'NA21095',
#  'NA21094',
#  'NA21093',
#  'NA21092',
#  'NA21091',
#  'NA21090',
#  'NA21089',
#  'NA21088',
#  'NA21087',
#  'NA21086',
#  'NA20911',
#  'NA20910',
#  'NA20908',
#  'NA20906',
#  'NA20905',
#  'NA20904',
#  'NA20903',
#  'NA20902',
#  'NA20901',
#  'NA20900',
#  'NA20899',
#  'NA20897',
#  'NA20896',
#  'NA20895',
#  'NA20894',
#  'NA20892',
#  'NA20891',
#  'NA20890',
#  'NA20889',
#  'NA20888',
#  'NA20887',
# ...

# %%
es.get_populations()
# Out:
# ['ACB',
#  'ASW',
#  'BEB',
#  'CDX',
#  'CEU',
#  'CHB',
#  'CHS',
#  'CLM',
#  'ESN',
#  'FIN',
#  'GBR',
#  'GIH',
#  'IBS',
#  'ITU',
#  'JPT',
#  'KHV',
#  'LWK',
#  'GWD',
#  'MSL',
#  'MXL',
#  'PEL',
#  'PJL',
#  'PUR',
#  'STU',
#  'TSI',
#  'YRI']

# %%
a[0].calls
# Out:
# 9463',
#   'genotype': [1, 0],
#   'info': {},
#   'callSetId': '3:NA19463',
#   'genotypeLikelihood': [],
#   'phaseset': ''},
#  {'callSetName': 'HG00240',
#   'genotype': [0, 0],
#   'phaseset': '',
#   'callSetId': '3:HG00240',
#   'info': {},
#   'genotypeLikelihood': []},
#  {'genotypeLikelihood': [],
#   'info': {},
#   'callSetId': '3:HG03583',
#   'phaseset': '',
#   'genotype': [0, 1],
#   'callSetName': 'HG03583'},
#  {'callSetName': 'HG02494',
#   'genotype': [0, 0],
#   'phaseset': '',
#   'info': {},
#   'callSetId': '3:HG02494',
#   'genotypeLikelihood': []},
#  {'genotype': [0, 0],
#   'callSetName': 'NA19153',
#   'info': {},
#   'callSetId': '3:NA19153',
#   'genotypeLikelihood': [],
#   'phaseset': ''},
#  {'phaseset': '',
#   'callSetId': '3:HG01815',
#   'info': {},
#   'genotypeLikelihood': [],
#   'callSetName': 'HG01815',
#   'genotype': [0, 0]},
#  {'callSetName': 'NA18639',
#   'genotype': [0, 0],
#   'phaseset': '',
#   'callSetId': '3:NA18639',
# ...

# %%
for i in range(1000):
    print(a[i].alternateBases)

# %%
b[0]

# %%
a = es.get_variants(3,17671934, 17681934, tuple(es.get_samples())

# %%
import pickle

# %%
with  open("variants", 'wb') as file1:
    pickle.dump(es, file1)

# %%
aa = gentype.Ensembl.load("variants")

# %%
samples = tuple(es.get_samples())

# %%
# Out:
# (3,
#  17671934,
#  17681934,
#  ('NA21144',
#   'NA21143',
#   'NA21142',
#   'NA21141',
#   'NA21137',
#   'NA21135',
#   'NA21133',
#   'NA21130',
#   'NA21129',
#   'NA21128',
#   'NA21127',
#   'NA21126',
#   'NA21125',
#   'NA21124',
#   'NA21123',
#   'NA21122',
#   'NA21120',
#   'NA21119',
#   'NA21118',
#   'NA21117',
#   'NA21116',
#   'NA21115',
#   'NA21114',
#   'NA21113',
#   'NA21112',
#   'NA21111',
#   'NA21110',
#   'NA21109',
#   'NA21108',
#   'NA21107',
#   'NA21106',
#   'NA21105',
#   'NA21104',
#   'NA21103',
#   'NA21102',
#   'NA21101',
#   'NA21100',
#   'NA21099',
#   'NA21098',
#   'NA21097',
#   'NA21095',
#   'NA21094',
#   'NA21093',
#   'NA21092',
#   'NA21091',
#   'NA21090',
#   'NA21089',
#   'NA21088',
#   'NA21087',
#   'NA21086',
#   'NA20911',
#   'NA20910',
#   'NA20908',
#   'NA20906',
#   'NA20905',
#   'NA20904',
#   'NA20903',
#   'NA20902',
#   'NA20901',
#   'NA20900',
#   'NA20899',
#   'NA20897',
#   'NA20896',
#   'NA20895',
# ...

# %%
varsi = list(aa.fetched_variants.values())[0]

# %%
inds = list(map(lambda x: gentype.Individual(x, "X", varsi), samples))

# %%
generate_X_matrix(inds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-83b343b1b3ff> in <module>
# ----> 1 generate_X_matrix(inds)
#
# NameError: name 'generate_X_matrix' is not defined
